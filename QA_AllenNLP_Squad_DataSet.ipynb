# %% [markdown]
# <a href="https://colab.research.google.com/github/hassansardar193/Natural_Language_Processing-Question_Answering/blob/main/QA_AllenNLP_Squad_DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Embedding, LSTM, Dense, Dropout, Input
from keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Define the input and output sequences
input_sequence = Input((max_len,))
output_sequence = Embedding(vocab_size, 100, input_length=max_len)(input_sequence)
output_sequence = LSTM(128)(output_sequence)
output_sequence = Dropout(0.5)(output_sequence)
output_sequence = Dense(64, activation='relu')(output_sequence)
output_sequence = Dense(1, activation='sigmoid')(output_sequence)

# Create the model
model = Model(input_sequence, output_sequence)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, batch_size=32, epochs=10)

# Evaluate the model
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f577cd3b9f8d> in <module>
#       4
#       5 # Define the input and output sequences
# ----> 6 input_sequence = Input((max_len,))
#       7 output_sequence = Embedding(vocab_size, 100, input_length=max_len)(input_sequence)
#       8 output_sequence = LSTM(128)(output_sequence)
#
# NameError: name 'max_len' is not defined

# %%
import allennlp
from allennlp.predictors import Predictor
from allennlp.data import DatasetReader
from allennlp.models import Model
from allennlp.training import Trainer
from allennlp.common.util import JsonDict

# Define a custom dataset reader to read in your dataset
class CustomDatasetReader(DatasetReader):
    def __init__(self):
        super().__init__()
    def _read(self, file_path: str) -> Iterable[JsonDict]:
       
class CustomModel(Model):
  def __init__(self):
        super().__init__()
  def forward(self, *inputs) -> Dict[str, torch.Tensor]:
        
# Create an instance of your custom dataset reader
dataset_reader = CustomDatasetReader()
# Read in your training dataset
train_dataset = dataset_reader.read('./path/to/train/dataset')
# Read in your validation dataset
validation_dataset = dataset_reader.read('./path/to/validation/dataset')

# Instantiate your custom model
model = CustomModel()
# Use the AllenNLP Trainer to train your model
trainer = Trainer(model=model,
                  optimizer=optimizer,
                  train_dataset=train_dataset,
                  validation_dataset=validation_dataset)
trainer.train()

# Once your model is trained, use it to make predictions on a test dataset
predictor = Predictor.from_path("path/to/your/model/directory", dataset_reader=dataset_reader)
test_dataset = dataset_reader.read('./path/to/test/dataset')
predictions = predictor.predict_batch_json(test_dataset)

# Compare the predicted answers to the actual answers to calculate accuracy and precision
correct_count = 0
total_count = 0
for example, prediction in zip(test_dataset, predictions):
    if example['answer'] == prediction['answer']:
        correct_count += 1
    total_count += 1

accuracy = correct_count / total_count
print("Accuracy: ", accuracy)
# Out:
#   File "<ipython-input-14-ad8a66656cf5>", line 14
#     class CM(Model):
#                     ^
# IndentationError: expected an indented block

# %%
class CustomModel(Model):
  def __init__(self):
        super().__init__()
  def forward(self, *inputs) -> Dict[str, torch.Tensor]:
# Out:
#   File "<ipython-input-16-87f0dd3bc280>", line 4
#     def forward(self, *inputs) -> Dict[str, torch.Tensor]:
#                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
# !pip install allennlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting allennlp
#   Downloading allennlp-2.10.1-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.2/730.2 KB 16.3 MB/s eta 0:00:00
# Collecting requests>=2.28
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.8/dist-packages (from allennlp) (1.21.6)
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from allennlp) (1.7.3)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.8/dist-packages (from allennlp) (0.3.6)
# Collecting pytest>=6.2.5
#   Downloading pytest-7.2.1-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 KB 36.7 MB/s eta 0:00:00
# Collecting torchvision<0.14.0,>=0.8.1
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 63.7 MB/s eta 0:00:00
# Collecting h5py>=3.6.0
#   Downloading h5py-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 96.5 MB/s eta 0:00:00
# Collecting cached-path<1.2.0,>=1.1.3
#   Downloading cached_path-1.1.6-py3-none-any.whl (26 kB)
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting lmdb>=1.2.1
#   Downloading lmdb-1.4.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.1/306.1 KB 34.9 MB/s eta 0:00:00
# Collecting sentencepiece>=0.1.96
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 38.8 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from allennlp) (0.7.0)
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.6 MB/s eta 0:00:00
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp) (3.19.6)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 56.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: traitlets>5.1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp) (5.7.1)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.2/248.2 KB 30.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from allennlp) (1.0.2)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.8/dist-packages (from allennlp) (4.64.1)
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp) (9.0.0)
# Collecting transformers<4.21,>=4.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 90.1 MB/s eta 0:00:00
# Collecting filelock<3.8,>=3.3
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.19.1.tar.gz (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.6/593.6 KB 49.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from allennlp) (3.7)
# Collecting torch<1.13.0,>=1.10.0
#   Downloading torch-1.12.1-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 964.0 kB/s eta 0:00:00
# Collecting spacy<3.4,>=2.1.0
#   Downloading spacy-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 50.2 MB/s eta 0:00:00
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 13.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 KB 21.3 MB/s eta 0:00:00
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.26.56-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 16.0 MB/s eta 0:00:00
# Collecting rich<13.0,>=12.1
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 KB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (2.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp) (21.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.6.5->allennlp) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.6.5->allennlp) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.6.5->allennlp) (2022.6.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp) (22.2.0)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp) (2.0.1)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.1->allennlp) (3.1.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (57.4.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.7)
# Collecting typer>=0.4.1
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.8)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.7.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.11)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.1/671.1 KB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.4.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision<0.14.0,>=0.8.1->allennlp) (7.1.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.9 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.15.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 KB 20.9 MB/s eta 0:00:00
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 11.1 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.56
#   Downloading botocore-1.29.56-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 66.1 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.11.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.0.16->allennlp) (3.0.9)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (2.6.1)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp) (2.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.30.0,>=1.29.56->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.8.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.58.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.4.8)
# Building wheels for collected packages: fairscale, termcolor, jsonnet, sacremoses, pathtools
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307251 sha256=b1d9ec2d73962bd6244895454382b9425f8988c734734be3b8ddc511e5f40f10
#   Stored in directory: /root/.cache/pip/wheels/77/4c/a4/f6c0eec2ec5c8ffca075e62b0329801f862e1f1b71422f456b
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4849 sha256=ff0069751999a8b041106281ef9372368fdea4469ee9ca9fcd6c8a07b9e227ba
#   Stored in directory: /root/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.19.1-cp38-cp38-linux_x86_64.whl size=6332995 sha256=2cab06636228e1eeff60e3bc96939aa9ac1d5f78a0c242a308b7a1203a784514
#   Stored in directory: /root/.cache/pip/wheels/64/ec/56/de861aae102c449ade2378772abbf9eb7e9acfe9a80f3e6036
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=8ad9dc402871a3b03b8bb68a2b7927a12d9b03752b0d44ef12777611d32720f9
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=0b602bbf0c9869e71206b732395bf970eee56a93cf941c484302fb7b5af23268
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built fairscale termcolor jsonnet sacremoses pathtools
# Installing collected packages: tokenizers, termcolor, sentencepiece, pathtools, lmdb, jsonnet, commonmark, urllib3, typer, torch, tensorboardX, smmap, shortuuid, setproctitle, sacremoses, rich, pydantic, pluggy, jmespath, iniconfig, h5py, filelock, exceptiongroup, docker-pycreds, base58, thinc, sentry-sdk, requests, pytest, gitdb, fairscale, botocore, torchvision, spacy, s3transfer, huggingface-hub, GitPython, wandb, transformers, boto3, cached-path, allennlp
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.2.0
#     Uninstalling termcolor-2.2.0:
#       Successfully uninstalled termcolor-2.2.0
#   Attempting uninstall: lmdb
#     Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.4
#     Uninstalling pydantic-1.10.4:
#       Successfully uninstalled pydantic-1.10.4
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.6
#     Uninstalling thinc-8.1.6:
#       Successfully uninstalled thinc-8.1.6
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.12.1 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.12.1 which is incompatible.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.2 which is incompatible.
# Successfully installed GitPython-3.1.30 allennlp-2.10.1 base58-2.1.1 boto3-1.26.56 botocore-1.29.56 cached-path-1.1.6 commonmark-0.9.1 docker-pycreds-0.4.0 exceptiongroup-1.1.0 fairscale-0.4.6 filelock-3.7.1 gitdb-4.0.10 h5py-3.8.0 huggingface-hub-0.10.1 iniconfig-2.0.0 jmespath-1.0.1 jsonnet-0.19.1 lmdb-1.4.0 pathtools-0.1.2 pluggy-1.0.0 pydantic-1.8.2 pytest-7.2.1 requests-2.28.2 rich-12.6.0 s3transfer-0.6.0 sacremoses-0.0.53 sentencepiece-0.1.97 sentry-sdk-1.14.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 spacy-3.3.2 tensorboardX-2.5.1 termcolor-1.1.0 thinc-8.0.17 tokenizers-0.12.1 torch-1.12.1 torchvision-0.13.1 transformers-4.20.1 typer-0.4.2 urllib3-1.26.14 wandb-0.12.21

# %%
import allennlp
from allennlp.predictors.predictor import Predictor
from allennlp.data import DatasetReader
from allennlp.models import Model
from allennlp.training import Trainer
from allennlp.common.util import JsonDict

# Define a custom dataset reader to read in your dataset
class CustomDatasetReader(DatasetReader):
    def __init__(self):
        super().__init__()
    def _read(self, file_path: str) -> Iterable[JsonDict]:
        # Define your read function here to read the dataset and return an iterable of JsonDict
        pass

class CustomModel(Model):
    def __init__(self):
        super().__init__()
    def forward(self, *inputs) -> Dict[str, torch.Tensor]:
        # Define your forward function here, to calculate the output from inputs
        pass

# Create an instance of your custom dataset reader
dataset_reader = CustomDatasetReader()
# Read in your training dataset
train_dataset = dataset_reader.read('./path/to/train/dataset')
# Read in your validation dataset
validation_dataset = dataset_reader.read('./path/to/validation/dataset')

# Instantiate your custom model
model = CustomModel()
# Create your optimizer
optimizer = optim.Adam(model.parameters())
# Use the AllenNLP Trainer to train your model
trainer = Trainer(model=model,
                  optimizer=optimizer,
                  train_dataset=train_dataset,
                  validation_dataset=validation_dataset)
trainer.train()

# Once your model is trained, use it to make predictions on a test dataset
predictor = Predictor.from_path("path/to/your/model/directory", dataset_reader=dataset_reader)
test_dataset = dataset_reader.read('./path/to/test/dataset')
predictions = predictor.predict_batch_json(test_dataset)

# Compare the predicted answers to the actual answers to calculate accuracy and precision
correct_count = 0
total_count = 0
for example, prediction in zip(test_dataset, predictions):
    if example['answer'] == prediction['answer']:
        correct_count += 1
    total_count += 1

accuracy = correct_count / total_count
print("Accuracy: ", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-e84a9d7693b9> in <module>
#       1 import allennlp
# ----> 2 from allennlp.predictors.predictor import Predictor
#       3 from allennlp.data import DatasetReader
#       4 from allennlp.models import Model
#       5 from allennlp.training import Trainer
#
# /usr/local/lib/python3.8/dist-packages/allennlp/predictors/__init__.py in <module>
#       7 a `Predictor` that wraps it.
#       8 """
# ----> 9 from allennlp.predictors.predictor import Predictor
#      10 from allennlp.predictors.sentence_tagger import SentenceTaggerPredictor
#      11 from allennlp.predictors.text_classifier import TextClassifierPredictor
#
# /usr/local/lib/python3.8/dist-packages/allennlp/predictors/predictor.py in <module>
#      12 from torch import backends
#      13
# ---> 14 from allennlp.common import Registrable, plugins
#      15 from allennlp.common.util import JsonDict, sanitize
#      16 from allennlp.data import DatasetReader, Instance
#
# /usr/local/lib/python3.8/dist-packages/allennlp/common/__init__.py in <module>
# ----> 1 from allennlp.common.from_params import FromParams
#       2 from allennlp.common.lazy import Lazy
#       3 from allennlp.common.params import Params
#       4 from allennlp.common.registrable import Registrable
#       5 from allennlp.common.tqdm import Tqdm
#
# /usr/local/lib/python3.8/dist-packages/allennlp/common/from_params.py in <module>
#      21
#      22 from allennlp.common.checks import ConfigurationError
# ---> 23 from allennlp.common.lazy import Lazy
#      24 from allennlp.common.params import Params
#      25
#
# /usr/local/lib/python3.8/dist-packages/allennlp/common/lazy.py in <module>
#       3 from typing import Callable, Generic, TypeVar, Type, Union, Optional, Dict, Any
#       4
# ----> 5 from allennlp.common.params import Params
#       6
#       7
#
# /usr/local/lib/python3.8/dist-packages/allennlp/common/params.py in <module>
#      31
#      32 from allennlp.common.checks import ConfigurationError
# ---> 33 from allennlp.common.file_utils import cached_path
#      34
#      35 logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.8/dist-packages/allennlp/common/file_utils.py in <module>
#      37 import warnings
#      38
# ---> 39 import cached_path as _cached_path
#      40 from cached_path import (  # noqa: F401
#      41     resource_to_filename as _resource_to_filename,
#
# /usr/local/lib/python3.8/dist-packages/cached_path/__init__.py in <module>
#      11 """
#      12
# ---> 13 from ._cached_path import cached_path
#      14 from .common import get_cache_dir, set_cache_dir
#      15 from .progress import get_download_progress
#
# /usr/local/lib/python3.8/dist-packages/cached_path/_cached_path.py in <module>
#      13 from .file_lock import FileLock
#      14 from .meta import Meta
# ---> 15 from .schemes import get_scheme_client, get_supported_schemes, hf_get_from_cache
#      16 from .util import (
#      17     _lock_file_path,
#
# /usr/local/lib/python3.8/dist-packages/cached_path/schemes/__init__.py in <module>
#       4 from cached_path.schemes.hf import hf_get_from_cache
#       5 from cached_path.schemes.http import HttpClient
# ----> 6 from cached_path.schemes.s3 import S3Client
#       7 from cached_path.schemes.scheme_client import SchemeClient
#       8
#
# /usr/local/lib/python3.8/dist-packages/cached_path/schemes/s3.py in <module>
#       6 from typing import Optional, Tuple
#       7
# ----> 8 import boto3
#       9 import botocore
#      10
#
# /usr/local/lib/python3.8/dist-packages/boto3/__init__.py in <module>
#      15
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      18
#      19 __author__ = 'Amazon Web Services'
#
# /usr/local/lib/python3.8/dist-packages/boto3/session.py in <module>
#      15 import os
#      16
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#      19 from botocore.exceptions import DataNotFoundError, UnknownServiceError
#
# /usr/local/lib/python3.8/dist-packages/botocore/session.py in <module>
#      24 import warnings
#      25
# ---> 26 import botocore.client
#      27 import botocore.configloader
#      28 import botocore.credentials
#
# /usr/local/lib/python3.8/dist-packages/botocore/client.py in <module>
#      13 import logging
#      14
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#      17 from botocore.auth import AUTH_TYPE_MAPS
#
# /usr/local/lib/python3.8/dist-packages/botocore/waiter.py in <module>
#      16 import jmespath
#      17
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#      20
#
# /usr/local/lib/python3.8/dist-packages/botocore/docs/__init__.py in <module>
#      13 import os
#      14
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      16
#      17
#
# /usr/local/lib/python3.8/dist-packages/botocore/docs/service.py in <module>
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#      16 from botocore.docs.waiter import WaiterDocumenter
#
# /usr/local/lib/python3.8/dist-packages/botocore/docs/client.py in <module>
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#
# /usr/local/lib/python3.8/dist-packages/botocore/docs/example.py in <module>
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#      15
#
# /usr/local/lib/python3.8/dist-packages/botocore/docs/shape.py in <module>
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      20
#      21
#
# /usr/local/lib/python3.8/dist-packages/botocore/utils.py in <module>
#      35 import botocore
#      36 import botocore.awsrequest
# ---> 37 import botocore.httpsession
#      38
#      39 # IP Regexes retained for backwards compatibility
#
# /usr/local/lib/python3.8/dist-packages/botocore/httpsession.py in <module>
#      20 from urllib3.exceptions import SSLError as URLLib3SSLError
#      21 from urllib3.util.retry import Retry
# ---> 22 from urllib3.util.ssl_ import (
#      23     DEFAULT_CIPHERS,
#      24     OP_NO_COMPRESSION,
#
# ImportError: cannot import name 'PROTOCOL_TLS' from 'urllib3.util.ssl_' (/usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
